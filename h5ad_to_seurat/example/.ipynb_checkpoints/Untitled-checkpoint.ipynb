# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import scanpy as sc
import igraph
import scvelo as scv
import loompy as lmp 
import anndata 
from scipy import io 
from scipy.sparse import coo_matrix, csr_matrix 
import os

# %%
adata = sc.read_h5ad("/rds/general/user/ph323/home/endometrium_epithelial.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10729 × 28614
#     obs: 'SampleID', 'log2p1_count', 'percent_mito', 'n_genes', 'DonorID', 'BiopsyType', 'Location', 'Binary Stage', 'Stage', 'Epithelial celltype', 'CellCycle Phase'
#     var: 'gene_ids', 'n_cells'
# ...

# %%
adata.obsm['X_umap'] = adata.obsm['X_umap_epithelial_curated']

# %%
sc.pl.umap(adata)

# %%
sc.pl.umap(adata, color = "SampleID")

# %%
sc.pl.umap(adata, color = 'Epithelial celltype')
